# %%
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# Out:
# Requirement already satisfied: numpy in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (2.4.6)
# Requirement already satisfied: pandas in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: matplotlib in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.25 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=9 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: seaborn in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from seaborn) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=9 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\LAKSHYA\anaconda3\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\LAKSHYA\\Desktop\\weekly task'

# %%
dataframe=pd.read_csv(r'C:\\Users\\LAKSHYA\\Desktop\\weekly task\\Zomato-Data-.csv')
print(dataframe.head())
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
def handleRate(value):
        value=str(value).split('/')
        value=value[0];
        return float (value)

dataframe['rate']=dataframe['rate'].apply(handleRate)
print(dataframe.head())
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
dataframe.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    str
#  1   online_order                 148 non-null    str
#  2   book_table                   148 non-null    str
#  3   rate                         148 non-null    float64
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    str
# dtypes: float64(1), int64(2), str(4)
# memory usage: 12.0 KB

# %%
print (dataframe.isnull().sum())
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %%
sns.countplot(x=dataframe['listed_in(type)'])
plt.xlabel("Type of restaurant")
# Out:
# Text(0.5, 0, 'Type of restaurant')

# %%
grouped_data = dataframe.groupby('listed_in(type)')['votes'].sum()
result = pd.DataFrame({'votes':grouped_data})
plt.plot(result, c='green',marker='o')
plt.xlabel('Type of restaurent')
plt.ylabel('Votes')
# Out:
# Text(0, 0.5, 'Votes')

# %%
pivot_table = dataframe.pivot_table(index='listed_in(type)', columns='online_order',
aggfunc='size', fill_value=0)
sns.heatmap(pivot_table, annot=True, cmap='YlGnBu', fmt='d')
plt.title('Heatmap')
plt.xlabel('Online Order')
plt.ylabel('Listed In (Type)')
plt.show()
